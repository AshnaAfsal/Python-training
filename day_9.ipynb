# %% [markdown]
# <a href="https://colab.research.google.com/github/AshnaAfsal/Python-training/blob/main/day_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# **SQL**
# -> SELECT ----FROM----WHERE-----
# 1->FROM   2->WHERE  3->SELECT
#
# SELECT * FROM TABLE  ORDER BY SVORE DESC
# 1-FROM  2- ORDER BY
#
#
# order by desc and order by asc
# 1st we need to order by the the 1st coloumn and the n wee want to orderby the next in already order by table
#
# ..DISTINCT -REMOVE DUPLICATE
#
# ..TOP-(LIMIT)-RESRICT THE NO OF ROWS RETURNED
#
# SELECT(5)---FROM(1)---WHERE(2)---GRROP BY(3) ----HAVING(4)-----ORDERBY(6)

# %% [markdown]
# ```
# **TREE:**
#  -> LEAF NODE
#  ->INTERNAL NODE
#  LEVEL-0 TO N
#  HIEGHT->NO OF LEVELS
#  TYPES OF TREE:
#  BINARY 0,1,2
#  ->BINARY SEARCH TREE
#  ->BALNACED TREE
#
# * FULL BINARY TREE
# * DEGENERATED 1 CHILD
# *   LEFTSKEW
# *   RIGHT SKEW
#
# 1.   COMPLETE L->R
# 2.   PERFECT TREE
# 3.   BALANCED
#
# *   RED BLACK
# *   BST
# *   AVIAL
#
#  TERNARY 3
#  N-ARY TREE MORE THAN 3
#  ->DOUBLY LL

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None

tree=Node(10)
tree.left=Node(20)
tree.right=Node(30)
tree.left.left=Node(40)

# %% [markdown]
# ```
# inorder->L-ROOt-R
# preorder->R00t-L-R
# postorder->L-R-ROOT

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right= None

class BST:
  def __init__(self):
    self.root = None

  def _insert_recursive(self, current_node, data):
    if current_node is None:
      return Node(data)

    if data < current_node.data:
      current_node.left = self._insert_recursive(current_node.left, data)
    elif data > current_node.data:
      current_node.right = self._insert_recursive(current_node.right, data)
    # If data == current_node.data, do nothing (no duplicates)
    return current_node

  def insert(self, data):
    self.root = self._insert_recursive(self.root, data)

  def inorder(self, root):
    if root is None:
      return
    self.inorder(root.left)
    print(root.data)
    self.inorder(root.right)

tree=BST()
tree.insert(5)
tree.insert(3)
tree.insert(2)
tree.insert(7)
tree.insert(8)
tree.inorder(tree.root)
# Out:
# 2
# 3
# 5
# 7
# 8

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right= None

class BST:
  def __init__(self):
    self.root = None
  def insert(self,node,data):
    if node is None:
      return Node(data)
    if data<node.data:
      node.left=self.insert(node.left,data)
    elif data>node.data:
      node.right=self.insert(node.right,data)
    return node
  def inorder(self,root):
    if root is None:
      return
    self.inorder(root.left)
    print(root.data)
    self.inorder(root.right)

tree=BST()
tree.root=tree.insert(tree.root,5)
tree.root=tree.insert(tree.root,3)
tree.root=tree.insert(tree.root,2)
tree.root=tree.insert(tree.root,7)
tree.root=tree.insert(tree.root,8)
tree.root=tree.insert(tree.root,1)
tree.inorder(tree.root)
# Out:
# 1
# 2
# 3
# 5
# 7
# 8

# %% [markdown]
# ```
# TREE - LEETCODE QUESTIONS
# ->100
# ->101
# ->112
# ->222
# ->226
# ->235
# ->257
