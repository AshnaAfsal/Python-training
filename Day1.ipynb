# %% [markdown]
# <a href="https://colab.research.google.com/github/AshnaAfsal/Python-training/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Brothers trying to buy a watermelon of ev
# en weight and divide into even weight

# %%
w=int(input())
if w%2!=0 or w==2:
 print("No")
else:
  print("Yes")
# Out:
# 8
# Yes

# %%
w=int(input())
if w%2!=0 or w==2:
 print("No")
else:
  print("Yes")
  x=w//2
  if(x%2==0):
    print(x,x)
  else:
    print(x-1,x+1)
# Out:
# 6
# Yes
# 2 4

# %% [markdown]
# Elephant want to travel to his friends house

# %%
x=int(input())
if x<5:
  print(1)
elif x%5==0:
  print(x//5)
else:
  print(x//5+1)
# Out:
# 11
# 3

# %% [markdown]
# Two bear gaining weight in year

# %%
l,b=map(int,input().split())
year=0
while(l<=b):
 l*=3
 b*=2
 year+=1
print(year)
# Out:
# 4 7
# 2

# %% [markdown]
# subway tickets

# %%
#a normal ticket charge
#b special ticket charge
#n total no of days
#m no of days can be travel using special ticket
n,m,a,b=map(int,input().split())
if a*m<b:
  print(a*n)
else:
  print(((n//m)*b)+min(b,(n%m)*a))
# Out:
# 6 2 1 2
# 6

# %%
# !git config --global user.name "AshnaAfsal"
# !git config --global user.email "axhu5272gmail.com"

# %%
l=mapinput().split()

# %% [markdown]
# # New Section
